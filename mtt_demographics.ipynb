# %%
# Library to supress warnings or deprecation notes 
import warnings
warnings.filterwarnings('ignore')

# Libraries to help with reading and manipulating data
import numpy as np
import pandas as pd

# Libraries to help with data visualization
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('~/Downloads/mtt-demographics.csv')
df.head()
# Out:
#   Gender   Age  Years Of Service     Org. Location Job Category
# 0      F  29.0              0.17         Baltimore         Crew
# 1      F  30.0              0.75         Baltimore         CREW
# 2      F  26.0              3.25         Baltimore       OFFICE
# 3      F  48.0             14.58        Charleston       Office
# 4      F  58.0             10.67  Corporate Office       Office

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 707 entries, 0 to 706
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Gender            707 non-null    object
#  1   Age               705 non-null    float64
#  2   Years Of Service  707 non-null    float64
#  3   Org. Location     707 non-null    object
#  4   Job Category      707 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 27.7+ KB

# %%
df.Age.value_counts()
# Out:
# 63.0    22
# 61.0    22
# 24.0    22
# 26.0    22
# 34.0    20
#         ..
# 18.0     2
# 19.0     1
# 17.0     1
# 72.0     1
# 88.0     1
# Name: Age, Length: 62, dtype: int64

# %%
cols=['Age','Years Of Service']

# %%
for i in cols:
    sns.boxplot(x=df[i])
    plt.show()

# %%
df[df['Years Of Service'] <41]
# Out:
#     Gender   Age  Years Of Service     Org. Location Job Category
# 0        F  29.0              0.17         Baltimore         Crew
# 1        F  30.0              0.75         Baltimore         CREW
# 2        F  26.0              3.25         Baltimore       OFFICE
# 3        F  48.0             14.58        Charleston       Office
# 4        F  58.0             10.67  Corporate Office       Office
# ..     ...   ...               ...               ...          ...
# 702      M  45.0              1.75        Wilmington         crew
# 703      M  22.0              0.42        Wilmington         Crew
# 704      M  60.0             18.83        Wilmington       Office
# 705      M  59.0             27.00        Wilmington       Office
# 706      M  35.0              0.08        Wilmington         Pier
#
# [703 rows x 5 columns]

# %%
df[df['Years Of Service'] > 41]
# Out:
#     Gender   Age  Years Of Service     Org. Location Job Category
# 184      M  88.0             62.17  Corporate Office       Office
# 196      M  68.0             42.83  Corporate Office       Office
# 320      M  65.0             44.42          New York       Office
# 339      M  62.0             42.08          New York       Office

# %%
df = df[df['Years Of Service'] <41]

# %%
df[df['Years Of Service'] > 41]
# Out:
# Empty DataFrame
# Columns: [Gender, Age, Years Of Service, Org. Location, Job Category]
# Index: []

# %%
for i in cols:
    sns.boxplot(x=df[i])
    plt.show()

# %%
df[df['Years Of Service'] > 40]
# Out:
#     Gender   Age  Years Of Service     Org. Location Job Category
# 194      M  70.0             40.08  Corporate Office       Office

# %%
df = df[df['Years Of Service'] <40]

# %%
for i in cols:
    sns.boxplot(x=df[i])
    plt.show()

# %%
df[df['Years Of Service'] < 40]
# Out:
#     Gender   Age  Years Of Service     Org. Location Job Category
# 0        F  29.0              0.17         Baltimore         Crew
# 1        F  30.0              0.75         Baltimore         CREW
# 2        F  26.0              3.25         Baltimore       OFFICE
# 3        F  48.0             14.58        Charleston       Office
# 4        F  58.0             10.67  Corporate Office       Office
# ..     ...   ...               ...               ...          ...
# 702      M  45.0              1.75        Wilmington         crew
# 703      M  22.0              0.42        Wilmington         Crew
# 704      M  60.0             18.83        Wilmington       Office
# 705      M  59.0             27.00        Wilmington       Office
# 706      M  35.0              0.08        Wilmington         Pier
#
# [702 rows x 5 columns]

# %%
sns.displot(df['Age'], kde=True, height=5, aspect=2)
plt.title('Age Distribution', size=16, )
plt.ylabel('count');

# %%
plt.figure(figsize=(20,8))
sns.swarmplot(x='Age', y='Years Of Service', data=df)
plt.show()

# %%
plt.figure(figsize=(20,8))
sns.swarmplot(x='Org. Location', y='Age', data=df)
plt.show()
